# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('GO_GO_in_GO 0202.csv',index_col=0)

# %%
GO_list = list(set(pd.read_csv(r"D:\Herb数据库\version2\edge\Protein_GO\Protein_GO_filtered_in_GO.csv",index_col=0)['GO_id']))
data_filtered = data.query("GO_id1 in @GO_list")

# %%
len(set(data_filtered['GO_id1'])),len(set(data_filtered['GO_id2'])),len(set(data_filtered['GO_id1'])|set(data_filtered['GO_id1']))
# Out:
# (7657, 7190, 7657)

# %%
data_filtered.to_csv("GO_GO_filtered_in_GO.csv")
