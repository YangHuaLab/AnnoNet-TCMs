# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Protein_GO_in_GO.txt',sep='\t')[['Gene_name','GO_id','Evidence_code','Aspect']]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_34472\1562980343.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('Protein_GO_in_GO.txt',sep='\t')[['Gene_name','GO_id','Evidence_code','Aspect']]

# %%
experimental_codes = ['EXP','IDA','IPI','IMP','IGI','IEP','HTP','HDA','HMP','HGI','HEP']
Target_in_network = list(set(pd.read_csv(r"D:\Herb数据库\version2\node\Target_info_in_physical_network_and_experimental.csv",index_col=0)['Gene_name']))

# %%
data_filtered = data.query("Evidence_code in @experimental_codes and Aspect=='P' and Gene_name in @Target_in_network")

# %%
len(set(data_filtered['GO_id'])),len(set(data_filtered['Gene_name']))
# Out:
# (7688, 9159)

# %%
data_filtered.to_csv("Protein_GO_filtered_in_GO.csv")
